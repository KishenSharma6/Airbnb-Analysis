# %% [markdown]
# Introduction

# %%
from IPython.display import Image
from IPython.display import HTML
html1 = '<img src="picture.jpg" width="240" height="240" align="center"/>'
HTML(html1)
# Out:
# <img src="picture.jpg" width="240" height="240" align="center"/>

# %%
#Set path to listings EDA images
EDA_path = r'C:\Users\kishe\Documents\Data Science\Projects\Python Projects\In Progress\Air BnB - SF\Visualizations\01_Listings_EDA_Visualizations'

# %%
Image(filename = EDA_path + "/Geopandas_Avg_Rental.png", width=1500, height=1500)

# %%
Image(filename = EDA_path + "/Geopandas_Num_Bookings.png", width=500, height=600)

# %%
Image(filename = EDA_path + "/avg_per_night_rental.png", width=500, height=600)

# %%
Image(filename = EDA_path + "/med_per_month_rental.png", width=500, height=600)

# %%
Image(filename = EDA_path + "/med_rental_by_day.png", width=500, height=600)
